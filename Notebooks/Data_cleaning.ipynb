# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from IPython.display import display
import scipy as sp
import os
from unidecode import unidecode
import datetime

# %%
os.chdir('/Users/samuel/Documents/Projets/Reco_movies')

# %%
#Initial Database
df= pd.read_csv("Data/tmdb_movies_data.csv",sep=";",engine='python')
df.head()
# Out:
#        id    imdb_id popularity     budget     revenue  \
# 0  135397  tt0369610  32.985763  150000000  1513528810
# 1   76341  tt1392190  28.419936  150000000   378436354
# 2  262500  tt2908446  13.112507  110000000   295238201
# 3  140607  tt2488496  11.173104  200000000  2068178225
# 4  168259  tt2820852   9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10879 entries, 0 to 10878
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10879 non-null  object
#  1   imdb_id               10869 non-null  object
#  2   popularity            10879 non-null  object
#  3   budget                10876 non-null  object
#  4   revenue               10875 non-null  object
#  5   original_title        10875 non-null  object
#  6   cast                  10797 non-null  object
#  7   homepage              2945 non-null   object
#  8   director              10830 non-null  object
#  9   tagline               8051 non-null   object
#  10  keywords              9374 non-null   object
#  11  overview              10860 non-null  object
#  12  runtime               10511 non-null  object
#  13  genres                10486 non-null  object
#  14  production_companies  9529 non-null   object
# ...

# %%
df.shape
# Out:
# (10879, 22)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
#Duplicate rows
df[df.duplicated(keep=False)]
# Out:
#          id    imdb_id popularity    budget revenue original_title  \
# 2091  42194  tt0411951    0.59643  30000000  967000         TEKKEN
# 2092  42194  tt0411951    0.59643  30000000  967000         TEKKEN
#
#                                                    cast homepage  \
# 2091  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2092  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ... runtime genres  \
# 2091  Dwight H. Little  Survival is no game  ...     NaN    NaN
# 2092  Dwight H. Little  Survival is no game  ...     NaN    NaN
#
#      production_companies release_date vote_count vote_average release_year  \
# 2091                  NaN          NaN        NaN          NaN          NaN
# 2092                  NaN          NaN        NaN          NaN          NaN
#
#       budget_adj  revenue_adj  Unnamed: 21
# 2091         NaN          NaN          NaN
# 2092         NaN          NaN          NaN
#
# ...

# %%
#Drop duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10878, 22)

# %%
#drop useless and duplicates columns
df.drop(['id','imdb_id','homepage','budget','revenue','Unnamed: 21','tagline','keywords'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#   popularity                original_title  \
# 0  32.985763                Jurassic World
# 1  28.419936            Mad Max: Fury Road
# 2  13.112507                     Insurgent
# 3  11.173104  Star Wars: The Force Awakens
# 4   9.335014                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# ...

# %%
df.shape
# Out:
# (10878, 14)

# %%
#Missing values by columns
df.isna().sum()
# Out:
# popularity                 0
# original_title             4
# cast                      82
# director                  49
# overview                  19
# runtime                  367
# genres                   392
# production_companies    1349
# release_date             371
# vote_count               371
# vote_average             371
# release_year             371
# budget_adj               371
# revenue_adj              371
# dtype: int64

# %%
#Drop rows with missing values
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (9467, 14)

# %%
df.isna().sum()
# Out:
# popularity              0
# original_title          0
# cast                    0
# director                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
#keep the principal production company
df.production_companies = df.production_companies.str.split('|').str[0]

# %%
df['cast'] = df.cast.str.split('|').apply(lambda x : ', '.join(x))

# %%
#keep the 3 principal genres
df['genres'] = df.genres.str.split('|').str[0:3].apply(lambda x : ', '.join(x))

# %%
df.head()
# Out:
#   popularity                original_title  \
# 0  32.985763                Jurassic World
# 1  28.419936            Mad Max: Fury Road
# 2  13.112507                     Insurgent
# 3  11.173104  Star Wars: The Force Awakens
# 4   9.335014                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...   Colin Trevorrow
# 1  Tom Hardy, Charlize Theron, Hugh Keays-Byrne, ...     George Miller
# 2  Shailene Woodley, Theo James, Kate Winslet, An...  Robert Schwentke
# 3  Harrison Ford, Mark Hamill, Carrie Fisher, Ada...       J.J. Abrams
# 4  Vin Diesel, Paul Walker, Jason Statham, Michel...         James Wan
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# ...

# %%
#Unidecode
for col in ['original_title','cast','director','overview','genres']:
    df[col] = df[col].apply(lambda x : unidecode(x))

# %%
#Convert objects columns to numeric
cols = ['popularity','runtime','vote_count']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
#Convert release_date to datetime
df['release_date'] = pd.to_datetime(df['release_date'],errors='coerce')

# %%
#When the format is DD/MM/YY the year is not the good one ( ex : 01/01/66 is transformed in 01-01-2066)
def year_correction(date):
    current_date = datetime.datetime.now()
    if date > current_date:
        date = date.replace(year=date.year - 100)
    return date

# %%
df['release_date'] = df['release_date'].apply(year_correction)

# %%
#Missing values
df.loc[df.release_date.isna() == True]
# Out:
#       popularity    original_title  \
# 7267         NaN   Catholic school
#
#                                                    cast  \
# 7267   Ralph is considered something of a joke among...
#
#                                                director  \
# 7267   winning the Boston Marathon.  Coached by a yo...
#
#                                             overview  runtime genres  \
# 7267   Ralph applies himself to his unlikely mission      NaN     95
#
#      production_companies release_date  vote_count  vote_average  \
# 7267               Comedy          NaT         NaN          14.0
#
#       release_year  budget_adj  revenue_adj
# 7267           6.3      2004.0          0.0

# %%
#Convert release_year to datetime and keep only good format dates
df['release_year'] = df['release_date'].dt.year.astype('O')

# %%
#Creating columns for month and day released
df['release_day'] = df['release_date'].dt.day_name()
df['release_month'] = df['release_date'].dt.month_name()

# %%
#drop missing values
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (9466, 16)

# %%
df.dtypes
# Out:
# popularity                     float64
# original_title                  object
# cast                            object
# director                        object
# overview                        object
# runtime                        float64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# vote_count                     float64
# vote_average                   float64
# release_year                    object
# budget_adj                     float64
# revenue_adj                    float64
# release_day                     object
# release_month                   object
# dtype: object

# %%
#Creating a column profit
df['PROFIT'] = df['revenue_adj'] - df['budget_adj']

# %%
#Renaming columns and reset index
df.rename(str.upper, axis=1, inplace=True)
df.rename(columns={"BUDGET_ADJ": "BUDGET", "REVENUE_ADJ": "REVENUE"}, inplace=True)
df.reset_index(drop = True, inplace=True)

# %%
#reindexing columns
df = df.reindex(columns=[
 'ORIGINAL_TITLE',
 'CAST',
 'DIRECTOR',
 'OVERVIEW',
 'GENRES',
 'PRODUCTION_COMPANIES',
 'RUNTIME',
 'RELEASE_DATE',
 'RELEASE_YEAR',
 'RELEASE_MONTH',
 'RELEASE_DAY',
 'BUDGET',
 'REVENUE',
 'PROFIT',
 'VOTE_COUNT',
 'VOTE_AVERAGE',
 'POPULARITY'    
])

# %%
df.head()
# Out:
#                  ORIGINAL_TITLE  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 CAST          DIRECTOR  \
# 0  Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...   Colin Trevorrow
# 1  Tom Hardy, Charlize Theron, Hugh Keays-Byrne, ...     George Miller
# 2  Shailene Woodley, Theo James, Kate Winslet, An...  Robert Schwentke
# 3  Harrison Ford, Mark Hamill, Carrie Fisher, Ada...       J.J. Abrams
# 4  Vin Diesel, Paul Walker, Jason Statham, Michel...         James Wan
#
#                                             OVERVIEW  \
# 0  Twenty-two years after the events of Jurassic ...
# 1  An apocalyptic story set in the furthest reach...
# 2  Beatrice Prior must confront her inner demons ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
# ...

# %%
df.shape
# Out:
# (9466, 17)

# %%
#save final Database in a csv file
df.to_csv('Data/imdb_cleaned_data.csv', decimal = ',')
